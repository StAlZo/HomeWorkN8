# %%
url = 'https://drive.google.com/file/d/1THFxfHidFuWpNojv4Uh9f4V8eKNtKOTB/view?usp=sharing'
url = 'https://drive.google.com/uc?id=' + url.split('/')[-2]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(url)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
np.where(pd.isnull(df))
# Out:
# (array([  0,   2,   4,   5,   5,   7,   8,   9,  12,  13,  14,  15,  16,
#          17,  17,  18,  19,  19,  20,  22,  24,  25,  26,  26,  28,  28,
#          29,  29,  30,  31,  32,  32,  33,  34,  35,  36,  36,  37,  38,
#          39,  40,  41,  42,  42,  43,  44,  45,  45,  46,  46,  47,  47,
#          48,  48,  49,  50,  51,  53,  55,  56,  57,  58,  59,  60,  61,
#          63,  64,  64,  65,  65,  67,  68,  69,  70,  71,  72,  73,  74,
#          76,  76,  77,  77,  78,  79,  80,  81,  82,  82,  83,  84,  85,
#          86,  87,  87,  89,  90,  91,  93,  94,  95,  95,  98,  99, 100,
#         101, 101, 103, 104, 105, 106, 107, 107, 108, 109, 109, 111, 112,
#         113, 114, 115, 116, 117, 119, 120, 121, 121, 122, 125, 126, 126,
#         127, 128, 129, 130, 131, 132, 133, 134, 135, 138, 140, 140, 141,
#         142, 143, 144, 145, 146, 147, 149, 150, 152, 153, 154, 154, 155,
#         156, 157, 158, 158, 159, 159, 160, 161, 162, 163, 164, 165, 166,
# ...

# %% [markdown]
# вываываы

# %%
# кол-во пустых ячеек
df.isnull().sum().sum()
# Out:
# 2

# %%
df.Age[df.Age.isna()] = df.Age.mean()
df.Cabin[df.Cabin.isna()] = 'EEE'
df.Embarked[df.Embarked.isna()] = 'S'
df
# Out:
# <ipython-input-8-7864c11816d9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Age[df.Age.isna()] = df.Age.mean()
# <ipython-input-8-7864c11816d9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Cabin[df.Cabin.isna()] = 'EEE'
# <ipython-input-8-7864c11816d9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Embarked[df.Embarked.isna()] = 'S'
#      PassengerId  Survived  Pclass  \
# ...

# %% [markdown]
# минимальное и максимальное значение в каждом столбце

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.870561    0.523008
# std     257.353842    0.486592    0.836071   14.597668    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   21.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.000000    0.000000
# 75%     668.500000    1.000000    3.000000   39.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Кол-во уникальных значений в признаках

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df['Pclass'].hist()
# Out:
# <Axes: >
